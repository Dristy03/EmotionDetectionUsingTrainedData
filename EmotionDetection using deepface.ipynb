# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img = cv2.imread('happy.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [01:12<00:00, 18.22s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 1.0144939500794276e-26,
#   'disgust': 0.0,
#   'fear': 0.0,
#   'happy': 99.99998807907104,
#   'sad': 3.5447970814199053e-26,
#   'surprise': 3.27011193396482e-16,
#   'neutral': 1.766055675034295e-05},
#  'dominant_emotion': 'happy',
#  'age': 23,
#  'gender': 'Woman',
#  'race': {'asian': 24.737301468849182,
#   'indian': 10.614804923534393,
#   'black': 2.137264795601368,
#   'white': 7.693787664175034,
#   'middle eastern': 1.1557369492948055,
#   'latino hispanic': 53.661102056503296},
#  'dominant_race': 'latino hispanic'}

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1, 4)

for (x, y, w, h) in faces:
    cv2.rectangle (img, (x+10,y+10), (x+w, y+h), (0, 255, 0), 5)
    cv2.putText(img, predictions['dominant_emotion'],(0,50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
